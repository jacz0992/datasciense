# %%
import pandas as pd

# %% [markdown]
# ### Dataset sobre las ventas

# %% [markdown]
# Variables Potenciales para las ventas de amazon: diría que claramente todo lo que me ayudaría a identificar productos que mejor se venden, los que no y una infinidad de variables para poder controlar o emprender un nuevo negocio de ventas en Amazon

# %%
pd.read_csv('amazon_sells.csv')
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# ### Datasets de clientes de banca

# %% [markdown]
# Variables Potenciales para clientes de banca: poder saber cual es la necesida de los productos financieros para un mercado especifico e inclusive segmentar el grupo objetivo para llegar con marketing al mismo

# %%
pd.read_csv('BankChurners.csv')
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# ### Datasets de peliculas de accción

# %% [markdown]
# Variables Potenciales para las peliculas de acción: seria un poco mas de hobby para poder ver que se puede recomendar y que ver los fines de semana

# %%
pd.read_csv('action.csv')
# Out:
#          movie_id                         movie_name  year certificate  \
# 0       tt9114286     Black Panther: Wakanda Forever  2022       PG-13
# 1       tt1630029           Avatar: The Way of Water  2022       PG-13
# 2       tt5884796                              Plane  2023           R
# 3       tt6710474  Everything Everywhere All at Once  2022           R
# 4       tt5433140                             Fast X  2023         NaN
# ...           ...                                ...   ...         ...
# 52447  tt26743984                          Suicide 2  1999         NaN
# 52448  tt26744184                              Chaos  2023         NaN
# 52449  tt26744484                      Revolver Lily   NaN         NaN
# 52450  tt26744765                           The Wing   NaN         NaN
# 52451  tt26745202                       Vey Dharuvey   NaN         NaN
#
#        runtime                       genre  rating  \
# 0      161 min    Action, Adventure, Drama     6.9
# ...
